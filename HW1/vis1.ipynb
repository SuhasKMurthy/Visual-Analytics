# %%
import random
from bokeh.plotting import figure
from bokeh.io import output_notebook, show
import pandas as pd
from bokeh.models import Legend, LegendItem
from bokeh.palettes import Viridis256

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="50451362-3b9f-4405-8a41-ca75b76f971c">Loading BokehJS ...</span>
#     </div>

# %%
rang = list(range(1800, 2015, 10))
df = pd.read_csv('population.csv')

df.dropna(subset=['1800'], inplace=True)
countries = df.iloc[1:, 0]
lcountries = list(countries)
    
random.shuffle(Viridis256)
x = Viridis256[0:len(lcountries)]
countries_dict = dict(zip(lcountries, x))
print(countries_dict)
# Out:
# {'Albania': '#F6E61F', 'Algeria': '#4FC369', 'American Samoa': '#26AC81', 'Andorra': '#23A883', 'Angola': '#8DD644', 'Anguilla': '#1F958B', 'Antigua and Barbuda': '#24848D', 'Argentina': '#3B518A', 'Armenia': '#287B8E', 'Aruba': '#472A79', 'Australia': '#218C8D', 'Austria': '#6DCE58', 'Azerbaijan': '#72CF55', 'Bahamas': '#A2DA37', 'Bahrain': '#46317E', 'Bangladesh': '#3BBA75', 'Barbados': '#F1E51C', 'Belarus': '#472575', 'Belgium': '#22898D', 'Belize': '#30678D', 'Benin': '#472C7B', 'Bermuda': '#22A784', 'Bhutan': '#2AB07E', 'Bolivia': '#3B508A', 'Bosnia and Herzegovina': '#21A685', 'Botswana': '#1E988A', 'Brazil': '#32628D', 'British Virgin Islands': '#443781', 'Brunei': '#471265', 'Bulgaria': '#92D741', 'Burkina Faso': '#3E4989', 'Burundi': '#2E6D8E', 'Cambodia': '#1FA187', 'Cameroon': '#482071', 'Canada': '#45085B', 'Cape Verde': '#20A585', 'Cayman Islands': '#423D84', 'Central African Republic': '#4DC26B', 'Chad': '#3A538B', 'Channel Islands': '#5EC961', 'Chile': '#1FA386', 'China': '#3D4B89', 'Colombia': '#218E8C', 'Comoros': '#23A982', 'Congo, Dem. Rep.': '#472878', 'Congo, Rep.': '#BADE27', 'Cook Is': '#460E61', 'Costa Rica': '#24868D', "Cote d'Ivoire": '#472777', 'Croatia': '#1E9A89', 'Cuba': '#287A8E', 'Cyprus': '#2E6B8E', 'Czech Republic': '#95D73F', 'Denmark': '#44BE70', 'Djibouti': '#355D8C', 'Dominica': '#45BF6F', 'Dominican Republic': '#472B7A', 'Ecuador': '#2C718E', 'Egypt': '#46307D', 'El Salvador': '#30B47A', 'Equatorial Guinea': '#481D6F', 'Eritrea': '#20918C', 'Estonia': '#42BE71', 'Ethiopia': '#2D6F8E', 'Faeroe Islands': '#24858D', 'Falkland Is (Malvinas)': '#A7DB33', 'Fiji': '#1F938B', 'Finland': '#7ED24E', 'France': '#DFE318', 'French Guiana': '#450558', 'French Polynesia': '#218D8C', 'Gabon': '#414186', 'Gambia': '#1F928C', 'Georgia': '#2B748E', 'Germany': '#37598C', 'Ghana': '#62CA5F', 'Gibraltar': '#20908C', 'Greece': '#423E85', 'Greenland': '#88D547', 'Grenada': '#482273', 'Guadeloupe': '#33608D', 'Guam': '#20A485', 'Guatemala': '#69CC5B', 'Guinea': '#3E4888', 'Guinea-Bissau': '#462D7C', 'Guyana': '#FDE724', 'Haiti': '#29788E', 'Holy See': '#2A758E', 'Honduras': '#228A8D', 'Hong Kong, China': '#79D151', 'Hungary': '#D4E11A', 'Iceland': '#90D643', 'India': '#33B679', 'Indonesia': '#53C567', 'Iran': '#453580', 'Iraq': '#440154', 'Ireland': '#2C728E', 'Isle of Man': '#1EA087', 'Israel': '#462F7C', 'Italy': '#39558B', 'Jamaica': '#471567', 'Japan': '#472676', 'Jordan': '#3DBB74', 'Kazakhstan': '#1E9B89', 'Kenya': '#9AD83C', 'Kiribati': '#31658D', 'North Korea': '#1E978A', 'South Korea': '#277D8E', 'Kuwait': '#FAE622', 'Kyrgyz Republic': '#267F8E', 'Lao': '#45327F', 'Latvia': '#1E998A', 'Lebanon': '#25828E', 'Lesotho': '#24AA82', 'Liberia': '#AADB32', 'Libya': '#AFDC2E', 'Liechtenstein': '#23898D', 'Lithuania': '#97D83E', 'Luxembourg': '#2D6E8E', 'Macao, China': '#3F4788', 'Macedonia, FYR': '#414286', 'Madagascar': '#E4E318', 'Malawi': '#CFE11C', 'Malaysia': '#1E9C89', 'Maldives': '#2EB27C', 'Mali': '#443982', 'Malta': '#38568B', 'Marshall Islands': '#47186A', 'Martinique': '#5BC862', 'Mauritania': '#33618D', 'Mauritius': '#CAE01E', 'Mayotte': '#25838D', 'Mexico': '#1E9F88', 'Micronesia, Fed. Sts.': '#81D34C', 'Moldova': '#25AB81', 'Monaco': '#39B976', 'Mongolia': '#3EBC73', 'Montenegro': '#440357', 'Montserrat': '#55C666', 'Morocco': '#3F4587', 'Mozambique': '#59C764', 'Myanmar': '#1E9E88', 'Namibia': '#365B8C', 'Nauru': '#48196B', 'Nepal': '#45347F', 'Netherlands': '#DAE218', 'New Caledonia': '#F8E621', 'New Zealand': '#46095C', 'Nicaragua': '#CDE01D', 'Niger': '#45065A', 'Nigeria': '#B7DD29', 'Niue': '#1E9D88', 'Northern Mariana Islands': '#471669', 'Norway': '#BFDF24', 'Oman': '#EEE51B', 'Pakistan': '#2B738E', 'Palau': '#1F968B', 'Panama': '#51C468', 'Papua New Guinea': '#E1E318', 'Paraguay': '#482374', 'Peru': '#471466', 'Philippines': '#433C84', 'Poland': '#23878D', 'Portugal': '#7CD24F', 'Puerto Rico': '#B5DD2B', 'Qatar': '#9FD938', 'Reunion': '#345F8D', 'Romania': '#47C06E', 'Russia': '#424085', 'R ...

# %%
rang = list(range(1800, 2015, 10))
rang = list(map(str, rang))

# use bokeh library to obtain the plot
plotTitle = "Population Growth"
p = figure(title=plotTitle, x_axis_label='Year', y_axis_label='Population',
           width=1000, height=500)

rang = list(map(str, rang))

items = []

rows = random.sample(range(1,df.shape[0]), 25)

#for i in range(1, df.shape[0]):
for i in rows:
    country = df.iloc[i, 0]
    col = countries_dict.get(df.iloc[i, 0])
    df1 = df.iloc[i, 1:]
    y1 = df1.loc[df1.index.isin(rang)]

    a = p.circle(x=rang, y=y1, size=3, color=col, alpha=0.8)
    items.append(LegendItem(label=country, renderers=[a]))
    p.line(x=rang, y=y1, line_width=2, color=col)

legend = Legend(items=items, location=(0, -30))

p.add_layout(legend, 'left')

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5fc8c574-d46c-4bbb-8f94-2d4f1c39e070"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("5fc8c574-d46c-4bbb-8f94-2d4f1c39e070");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5fc8c574-d46c-4bbb-8f94-2d4f1c39e070");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5fc8c574-d46c-4bbb-8f94-2d4f1c39e070' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f238b57c-225d-482b-ae06-3ae09eb0d394":{"roots":{"references":[{"attributes":{"source":{"id":"4ad0c89c-c38a-4bfd-ac8b-7e370ccf8cda","type":"ColumnDataSource"}},"id":"ed2d6a39-e6ec-4918-bc78-a9802e9d158a","type":"CDSView"},{"attributes":{"source":{"id":"23bc8e34-88fa-4c75-a541-70157e981de4","type":"ColumnDataSource"}},"id":"91ac5061-75de-4341-a1c6-07de0ace9281","type":"CDSView"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":